# %%
import pandas as pd

# %%
gen_df = pd.read_csv('generation.csv')
gen_df.head()
# Out:
#                   Unnamed: 0            Biomass Fossil Brown coal/Lignite  \
# 0                        NaN  Actual Aggregated         Actual Aggregated
# 1  2024-12-14 00:00:00+01:00              464.0                       0.0
# 2  2024-12-14 00:15:00+01:00              460.0                       0.0
# 3  2024-12-14 00:30:00+01:00              464.0                       0.0
# 4  2024-12-14 00:45:00+01:00              464.0                       0.0
#
#   Fossil Coal-derived gas         Fossil Gas   Fossil Hard coal  \
# 0       Actual Aggregated  Actual Aggregated  Actual Aggregated
# 1                     0.0            14864.0              288.0
# 2                     0.0            13236.0              288.0
# 3                     0.0            11972.0              288.0
# 4                     0.0            11560.0              288.0
#
#           Fossil Oil   Fossil Oil shale        Fossil Peat         Geothermal  \
# ...
